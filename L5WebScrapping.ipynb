# %% [markdown]
# This Jupyter notebook focuses on Web Scarpping

# %%
import requests # helps to download a web page
from bs4 import BeautifulSoup # helps in web scrapping

# %% [markdown]
# BeautifulSoup is a Python library for pulling data out of HTML and XML files. This is accomplished by representing the HTML as a set of objects with methods used to parse the HTML. We can navigate the HTML as a Tree and filter out what we are looking for.

# %% [raw]
# ### Consider the following HTML
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %%
# storing it as a string 
html = " <!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %%
# To parse the documnet pass it through BeautifulSoup constructor. The BeautifulSoup object represents the document as a nested data structure
soup = BeautifulSoup(html, 'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html><head><title>Page Title</title></head><body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>

# %%
# to display html as a nested structure
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %%
# Lets say we want to get the title of page and the name of the top paid player
tag_object = (soup.title)
print("tag object type:",type(tag_object))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %%
tag_object = soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
# Since tag object is a tree of objects. We can navigate down the branch as follows
tag_child = tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
# to access the parent
parent_tag = tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %%
sibling_tag = tag_object.next_sibling
sibling_tag
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling_2=sibling_tag.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %%
# salary of Steph curry using next sibling
salary_st = sibling_2.next_sibling
salary_st
# Out:
# <p> Salary: $85,000, 000 </p>

# %%
# if a tag has attributes, we can access the attributes by treating the tag like dictionary
tag_child['id']
# Out:
# 'boldest'

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %%
# NAVIGABLE STRING
# A string corresponds to a bit of text or context within a tag. 
# BeautifulSoup uses NavigableString classto contain this text
tag_string = tag_child.string
tag_string
# Out:
# 'Lebron James'

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %%
# A navigable string is similar to Python String or unicode string. The only difference is that it supports some of the features of BS library.
unicode_string = str(tag_string)
type(unicode_string)
# Out:
# str

# %% [raw]
# # FILTER
# # Filter allows us to find complex patterns. The simplest filter is a string. Now we will pass the string to different filter method and BeautifulSoup
# # will perform match against the exact string. Consider the following HTML
#
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %%
# We can store it in variable table
table = "%%html<table><tr><td id='flight' >Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"

# %%
table_bs = BeautifulSoup(table, 'html5lib')
table_bs
# Out:
# <html><head></head><body>%%html<table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody></table></body></html>

# %%
# find_all()
# This looks through all tags descendants and retrieves all that matches the filter

# %%
table_rows=table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr>]

# %%
first_row =table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
# If we iterate through the list, each element corresponds to row in the table
for i, row in enumerate(table_rows):
    print("row",i,"is",row)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# row 1 is <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>
# row 2 is <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>
# row 3 is <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr>

# %%
# Now as row is a cell object, we can simply apply method find_all to it and extract table cells in object cells using tag td.
for i, row in enumerate(table_rows):
    print('row', i)
    cells = row.find_all('td')
    for j,cell in enumerate(cells):
        print('colunm',j,"cell",cell)
# Out:
# row 0
# colunm 0 cell <td id="flight">Flight No</td>
# colunm 1 cell <td>Launch site</td>
# colunm 2 cell <td>Payload mass</td>
# row 1
# colunm 0 cell <td>1</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>
# colunm 2 cell <td>300 kg</td>
# row 2
# colunm 0 cell <td>2</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# colunm 2 cell <td>94 kg</td>
# row 3
# colunm 0 cell <td>3</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>
# colunm 2 cell <td>80 kg</td>

# %%
# if we use a list we can match against any item in that list
list_input=table_bs .find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>,
#  <td>80 kg</td>]

# %%
# ATTRIBUTES
# If the argument is not recoganized it will be turned into a filter o tag's attribute.

# %%
table_bs.find_all(id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %%
list_input=table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %%
table_bs.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %%
# Now find all elements with href value
table_bs.find_all(href = False)
# Out:
# [<html><head></head><body>%%html<table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody></table></body></html>,
#  <head></head>,
#  <body>%%html<table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody></table></body>,
#  <table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody></table>,
#  <tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody>,
#  <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>,
#  <a> </a>,
#  <td>80 kg</td>]

# %%
# Using soup object find the element with id attribute boldest
soup.find_all(id ='boldest')
# Out:
# [<b id="boldest">Lebron James</b>]

# %%
# With string you can search for strings instead of tags
table_bs.find_all(string="Florida")
# Out:
# ['Florida', 'Florida']

# %% [markdown]
# ### FIND METHOD
# ### Previously we noted that find_all() method scans the entire document looking for results
# ### It is usefull to use find() methos if looking for one element
#
# ### consider the following two tables
#
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"

# %%
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %% [markdown]
# ### EXERCISE
# Downloading and Scrapping the contents of a webpage

# %%
data = requests.get("http://www.ibm.com").text
data
# Out:
# '\n<!DOCTYPE HTML>\n<html lang="en-ca">\n<head>\n    \n    \n    \n    \n    <meta charset="UTF-8"/>\n    <meta name="languageCode" content="en"/>\n    <meta name="countryCode" content="ca"/>\n    <meta name="searchTitle" content="IBM - Canada"/>\n    <meta name="focusArea" content="No Contact Module"/>\n    <title>IBM - Canada</title>\n    <link rel="icon" href="/content/dam/adobe-cms/default-images/favicon.svg"/>\n    \n    <meta name="description" content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow."/>\n    <meta name="template" content="full-width-layout"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1"/>\n    <meta name="robots" content="index, follow"/>\n    \n    <link rel="canonical" href="https://www.ibm.com/ca-en"/>\n    <style id="anti-flicker-style">\n        :not(:defined) {\n          visibility: hidden;\n        }\n    </style>\n    <script type="text/javascript" id="anti-flicker-script">\n        (async () => {\n          await customElements.whenDefined(\'dds-masthead-container\');\n          document.getElementById(\'anti-flicker-style\').remove();\n          document.getElementById(\'anti-flicker-script\').remove();\n        })()\n    </script>\n    \n\n    <script type="text/javascript">\n        window.searchKey = {\n            templateName: \'full\\u002Dwidth\\u002Dlayout\',\n            taxonomylist: \'\',\n            L0Tag: \'CMaaS Focus Areas,Topics,Brands,Industries,Geography,Compliance Entities,Products\',\n        }\n    </script>\n\n<!--    <script>\n      (function(s,t,a,n){s[t]||(s[t]=a,n=s[a]=function(){n.q.push(arguments)},\n      n.q=[],n.v=2,n.l=1*new Date)})(window,"InstanaEumObject","ineum");\n      ineum(\'reportingUrl\', \'https://eum-orange-saas.instana.io\');\n      ineum(\'key\', \'QSUr0uqUS0m37yyre8ntkQ\');\n      ineum(\'trackSessions\');\n    </script>\n    <script defer crossorigin="anonymous" src="https://eum.instana.io/eum.min.js"></script>-->\n\n    \n        <link rel="alternate" hreflang="de-de" href="https://www.ibm.com/de-de"/>\n    \n        <link rel="alternate" hreflang="en-us" href="https://www.ibm.com/"/>\n    \n        <link rel="alternate" hreflang="en-ca" href="https://www.ibm.com/ca-en"/>\n    \n        <link rel="alternate" hreflang="ko-kr" href="https://www.ibm.com/kr-ko"/>\n    \n        <link rel="alternate" hreflang="pt-br" href="https://www.ibm.com/br-pt"/>\n    \n        <link rel="alternate" hreflang="en-in" href="https://www.ibm.com/in-en"/>\n    \n        <link rel="alternate" hreflang="es-es" href="https://www.ibm.com/es-es"/>\n    \n        <link rel="alternate" hreflang="zh-cn" href="https://www.ibm.com/cn-zh"/>\n    \n        <link rel="alternate" hreflang="es-mx" href="https://www.ibm.com/mx-es"/>\n    \n        <link rel="alternate" hreflang="fr-ca" href="https://www.ibm.com/ca-fr"/>\n    \n        <link rel="alternate" hreflang="it-it" href="https://www.ibm.com/it-it"/>\n    \n        <link rel="alternate" hreflang="id-id" href="https://www.ibm.com/id-id"/>\n    \n        <link rel="alternate" hreflang="en-au" href="https://www.ibm.com/au-en"/>\n    \n        <link rel="alternate" hreflang="en-uk" href="https://www.ibm.com/uk-en"/>\n    \n        <link rel="alternate" hreflang="fr-fr" href="https://www.ibm.com/fr-fr"/>\n    \n        <link rel="alternate" hreflang="ja-jp" href="https://www.ibm.com/jp-ja"/>\n    \n    <script type="text/javascript">\n        window.antiFlicker = {\n            active: true,\n            timeout: 3000\n        }\n    </script>\n    <script type="text/javascript">\n        var languageCode = document.getElementsByName(\'languageCode\')[0].content;\n        var countryCode = document.getElementsByName(\'countryCode\')[0].content;\n        var focusArea = document.getElementsByName(\'focusArea\')[0].content;\n        /* Define digital data object based on _appInfo object */\n       ...

# %%
soup = BeautifulSoup(data,"html5lib")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-ca"><head>
#
#
#
#
#     <meta charset="utf-8"/>
#     <meta content="en" name="languageCode"/>
#     <meta content="ca" name="countryCode"/>
#     <meta content="IBM - Canada" name="searchTitle"/>
#     <meta content="No Contact Module" name="focusArea"/>
#     <title>IBM - Canada</title>
#     <link href="/content/dam/adobe-cms/default-images/favicon.svg" rel="icon"/>
#
#     <meta content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow." name="description"/>
#     <meta content="full-width-layout" name="template"/>
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     <meta content="index, follow" name="robots"/>
#
#     <link href="https://www.ibm.com/ca-en" rel="canonical"/>
#     <style id="anti-flicker-style">
#         :not(:defined) {
#           visibility: hidden;
#         }
#     </style>
#     <script id="anti-flicker-script" type="text/javascript">
#         (async () => {
#           await customElements.whenDefined('dds-masthead-container');
#           document.getElementById('anti-flicker-style').remove();
#           document.getElementById('anti-flicker-script').remove();
#         })()
#     </script>
#
#
#     <script type="text/javascript">
#         window.searchKey = {
#             templateName: 'full\u002Dwidth\u002Dlayout',
#             taxonomylist: '',
#             L0Tag: 'CMaaS Focus Areas,Topics,Brands,Industries,Geography,Compliance Entities,Products',
#         }
#     </script>
#
# <!--    <script>
#       (function(s,t,a,n){s[t]||(s[t]=a,n=s[a]=function(){n.q.push(arguments)},
#       n.q=[],n.v=2,n.l=1*new Date)})(window,"InstanaEumObject","ineum");
#       ineum('reportingUrl', 'https://eum-orange-saas.instana.io');
#       ineum('key', 'QSUr0uqUS0m37yyre8ntkQ');
#       ineum('trackSessions');
#     </script>
#     <script defer crossorigin="anonymous" src="https://eum.instana.io/eum.min.js"></script>-->
#
#
#         <link href="https://www.ibm.com/de-de" hreflang="de-de" rel="alternate"/>
#
#         <link href="https://www.ibm.com/" hreflang="en-us" rel="alternate"/>
#
#         <link href="https://www.ibm.com/ca-en" hreflang="en-ca" rel="alternate"/>
#
#         <link href="https://www.ibm.com/kr-ko" hreflang="ko-kr" rel="alternate"/>
#
#         <link href="https://www.ibm.com/br-pt" hreflang="pt-br" rel="alternate"/>
#
#         <link href="https://www.ibm.com/in-en" hreflang="en-in" rel="alternate"/>
#
#         <link href="https://www.ibm.com/es-es" hreflang="es-es" rel="alternate"/>
#
#         <link href="https://www.ibm.com/cn-zh" hreflang="zh-cn" rel="alternate"/>
#
#         <link href="https://www.ibm.com/mx-es" hreflang="es-mx" rel="alternate"/>
#
#         <link href="https://www.ibm.com/ca-fr" hreflang="fr-ca" rel="alternate"/>
#
#         <link href="https://www.ibm.com/it-it" hreflang="it-it" rel="alternate"/>
#
#         <link href="https://www.ibm.com/id-id" hreflang="id-id" rel="alternate"/>
#
#         <link href="https://www.ibm.com/au-en" hreflang="en-au" rel="alternate"/>
#
#         <link href="https://www.ibm.com/uk-en" hreflang="en-uk" rel="alternate"/>
#
#         <link href="https://www.ibm.com/fr-fr" hreflang="fr-fr" rel="alternate"/>
#
#         <link href="https://www.ibm.com/jp-ja" hreflang="ja-jp" rel="alternate"/>
#
#     <script type="text/javascript">
#         window.antiFlicker = {
#             active: true,
#             timeout: 3000
#         }
#     </script>
#     <script type="text/javascript">
#         var languageCode = document.getElementsByName('languageCode')[0].content;
#         var countryCode = document.getElementsByName('countryCode')[0].content;
#         var focusArea = document.getElementsByName('focusArea')[0].content;
#         /* Define digital data object based on _appInfo object */
#         window.digitalData = {
#             page: {
#                 category: {
#                     primaryCategory: '',
#                 },
#                 pageInfo: {
#                     language: languageCode + '-' + countryCode,
#                     ibm: {
#                         siteID: 'MarketingAEM',
#                         country: countryCode,
#                         messaging: {
#                             routing: {
#                                 focusArea: focusArea,
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             },
#                             translation: {
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             }
#                         },
#                         sections: 0,
#                         patterns: 0
#                     }
#                 }
#             }
#         };
#     </script>
#
#
#         <meta content="https://www.ibm.com/ca-en" property="og:url"/>
#
#         <meta content="website" property="og:type"/>
#
#         <meta content="IBM - Canada" property="og:title"/>
#
#         <meta content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow." property="og:description"/>
#
#         <meta content="https://www.ibm.com/content/dam/adobe-cms/default-images/home-rail-01.jpg/_jcr_content/renditions/cq5dam.web.1280.1280.jpeg" property="og:image"/>
#
#
#
#
#     <script async="async" src="https://1.www.s81c.com/common/stats/ibm-common.js" type="text/javascript"></script>
#     <script src="https://s3.us.cloud-object-storage.appdomain.cloud/widget-registry/loader.js" type="application/javascript"></script>
#
#
#
# <link href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStylesCarbon.min.ACSHASH6b7f7aca22f55d7ccef93668b20d1b11.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStyles.min.ACSHASH762826f2cec6438d8e48c6548d113a1d.css" rel="stylesheet" type="text/css"/>
#
#
#
#
#     <link href="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/tag/v1/latest/plex.css" rel="stylesheet"/>
#     <link href="https://1.www.s81c.com/common/carbon/plex/sans.css" rel="stylesheet"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="content-page page basicpage publish" id="content-page-8872c5df99">
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="root container responsivegrid">
#
#
#
#
#     <div class="cmp-container" id="container-9225520bd9">
#
#         <div class="masthead">
#
#
#
#
#
#
#
#
# <dds-masthead-container auth-method="profile-api" data-endpoint="/common/carbon-for-ibm-dotcom/translations/masthead-footer/v2" has-contact="false"></dds-masthead-container>
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/tag/v2/alpha/masthead.min.js" type="module"></script>
#
#
#
#
# </div>
# <div class="leadspace-container container responsivegrid">
#
#
#
#
#     <div class="cmp-container" id="leadspace-container-519ea04062">
#
#         <div class="leadspace-expanded leadspace">
# <section class="theme-white">
#     <dds-video-cta-container>
#         <caem-container-leadspace size="super">
#
#
#
#                 <caem-heading id="leadspaceSimpleTitle" slot="heading" type="h1" type-style="display-01">
#
#
#
#   <dds-content-group-heading>
#
#
#
#
# <span class="enhanced-title">Build AI workflows you can trust </span>
#
#
#
#
#
#   </dds-content-group-heading>
#
#
#
#
#
#
#
#
#
#                 </caem-heading>
#
#
#             <caem-paragraph data-autoid="caem--paragraph" size="lead-in">
#                 <p>
#
#
#
#
#       Meet IBM’s next-generation AI and data platform that brings together new generative AI capabilities
#
#
#
#
#
#
#
# </p>
#             </caem-paragraph>
#
#
#                 <caem-button-group slot="action">
#
#
#
#
#
#
#
#
#
#
#
#
#     <caem-button-cta cta-type="local" href="https://dataplatform.cloud.ibm.com/registration/stepone?context=wx&amp;apps=data_science_experience,watson_machine_learning,cos,aiopenscale&amp;uucid=0cf8ca3f38ace12f&amp;utm_content=WXGWW&amp;regions=us-south" kind="primary" target="_self">
#         <span>Try for free</span>
#
#
#     </caem-button-cta>
#
#
#
#
#
#
#
#
#     <caem-button-cta cta-type="local" href="https://www.ibm.com/products/watsonx-governance" kind="tertiary" target="_blank">
#         <span>Meet watsonx.governance</span>
#
#
#     </caem-button-cta>
#
#
#
#
#
#                 </caem-button-group>
#
#
#
#
#
#
#
#
#
#
#
#
#         <caem-image-with-caption alt="watsonx.governance dashboard illustration" caption-alignment="left" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-xl.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded" id="image-869916719" slot="media">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-xl-retina.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-xl.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-l-retina.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-l.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-m-retina.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-m.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-s-retina.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-s.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-xs-retina.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/79/f8/homepage-leadspace-watson.component.crop-1by1-xs.ts=1703274968490.png/content/adobe-cms/ca/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#
#
#
#
#         </caem-image-with-caption>
#
#
#
#
#
#
#
#
#
#                     <dds-link-list slot="aside">
#                         <dds-link-list-heading aria-level="4" role="heading" slot="heading">
#
#
#
#
#
#       Latest News
#
#
#
#
#
#
#
#
#
#                         </dds-link-list-heading>
#
#
#
#
#
#
#         <caem-link-list-item cta-type="local" href="https://www.ibm.com/events/world-economic-forum" label="IBM at Davos" target="_self">
#
#
#
#
#
#
#
#             <p>Watch IBM leaders discuss building and using trusted AI</p>
#
#             <dds-card-cta-footer cta-type="local" href="https://www.ibm.com/events/world-economic-forum" target="_self">
#
#             </dds-card-cta-footer>
#         </caem-link-list-item>
#
#
#
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/link-list-item.min.js" type="module"></script>
#
#
#
#
#
#
#
#         <caem-link-list-item cta-type="local" href="https://www.ibm.com/case-studies/maple-leaf-sports-and-entertainment" label="Case study" target="_self">
#
#
#
#
#
#
#
#             <p>IBM and MLSE monitor cyberthreats and protect digitally engaged fans</p>
#
#             <dds-card-cta-footer cta-type="local" href="https://www.ibm.com/case-studies/maple-leaf-sports-and-entertainment" target="_self">
#
#             </dds-card-cta-footer>
#         </caem-link-list-item>
#
#
#
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/link-list-item.min.js" type="module"></script>
#
#                 </dds-link-list>
#
#
#         </caem-container-leadspace>
# </dds-video-cta-container>
# </section>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/paragraph.min.js" type="module"></script>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/heading.min.js" type="module"></script>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/leadspace.min.js" type="module"></script></div>
#
#
#     </div>
#
# </div>
# <div class="table-of-contents container responsivegrid">
# <dds-table-of-contents class="cmp-table-of-contents" data-autoid="dds--table-of-contents" data-cmp-is="table-of-contents" stickyoffset="48" toc-hide="hidden" toc-layout="horizontal">
#
#
#     <div class="cmp-table-of-contents" id="table-of-contents-548d09b2b3">
#
#         <div class="modular-container container responsivegrid">
#
#
#
#
#     <div class="cmp-container" id="modular-container-74a2a4a36b">
#
#         <div class="standalone-title enhanced-title text">
#
#
#
# <caem-heading type="h5">Recommended for you<br/></caem-heading>
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/heading.min.js" type="module"></script></div>
#
#
#     </div>
#
# </div>
# <div class="tile-group-container container responsivegrid">
#   <div class="bx--col">
#     <caem-tile-group>
#
#
#
#
#     <caem-tile cta-type="local" href="https://dataplatform.cloud.ibm.com/registration/stepone?context=wx&amp;apps=data_science_experience,watson_machine_learning,cos,aiopenscale&amp;uucid=0cf8ca3f38ace12f&amp;utm_content=WXGWW&amp;regions=us-south&amp;lnk=hpUSrc1" label="Free trial" target="_blank">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Preview of a watsonx dashboard" default-src="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-xl.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image" id="image--369081444" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-xl-retina.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-xl.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-l-retina.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-l.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-m-retina.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-m.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-s-retina.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-s.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-xs-retina.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/adobe-cms/default-images/home-rail-01.component.tile-card-xs.ts=1702664086072.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         Build workflows you can trust
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#
#
#     <caem-tile cta-type="local" href="https://www.ibm.com/ca-en/products/watsonx-orchestrate?lnk=hpUSrc2" label="AI assistance" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="An illustration of IBM Storage Protect" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-xl.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image" id="image-1331807391" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-xl-retina.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-xl.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-l-retina.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-l.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-m-retina.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-m.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-s-retina.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-s.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-xs-retina.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/72/54/storage-protect-p0c6278d1922da841.component.tile-card-xs.ts=1702664098965.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         Ease workloads with watsonx Orchestrate
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#     <caem-tile cta-type="local" href="https://www.ibm.com/ca-en/products/watsonx-code-assistant?lnk=hpUSrc3" label="watsonx Code Assistant " target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Illustration of colleagues viewing a giant dashboard" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-xl.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image" id="image--580975061" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-xl-retina.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-xl.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-l-retina.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-l.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-m-retina.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-m.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-s-retina.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-s.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-xs-retina.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/homepage/ul/g/a7/33/ibm-SPSS-home-card.component.tile-card-xs.ts=1702664115933.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         Accelerate code generation and developer productivity
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#     <caem-tile cta-type="local" href="https://www.ibm.com/watsonx" label="watsonx " target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Illustration of IBM's artificial intelligence divided into layers" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-xl.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image" id="image-1069552506" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-xl-retina.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-xl.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-l-retina.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-l.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-m-retina.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-m.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-s-retina.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-s.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-xs-retina.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/en-us/g/77/c5/watsonx-webpage-3168x1782.component.tile-card-xs.ts=1704279917454.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         The potential of your data powered by IBM artificial intelligence
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#
#     </caem-tile-group>
#   </div>
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script></div>
# <div class="intro-section"><div class="bx--col">
#     <caem-intro-section>
#
#         <caem-heading data-autoid="caem-heading" slot="heading" type="h2" type-style="expressive-heading-05">
#
#
#
#
#
#     Browse our technology
#
#
#
#
#
#
#
#
#
#             </caem-heading>
#
#         <caem-paragraph data-autoid="caem--paragraph" size="lead-in">
#             <div class="cms-richtext" data-dynamic-inner-content="description" id="rich-text-b49e11dcf1">
#     <p>From our flagship products for enterprise <a href="https://www.ibm.com/ca-en/cloud?lnk=hpUSbt1">hybrid cloud infrastructure</a> to next-generation AI, security and storage solutions, find the answer to your business challenge.</p>
#
#
#
#
#
#
# </div>
#         </caem-paragraph>
#
#
#             <dds-link-list type="vertical">
#
#
#
#
#
#         <dds-video-cta-container>
#             <dds-link-list-item-cta cta-type="local" href="https://www.ibm.com/ca-en/products?lnk=hpUSbt2" icon-placement="right" role="listitem" target="_self">
#                 View all products
#
#             </dds-link-list-item-cta>
#         </dds-video-cta-container>
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-video-cta-container>
#             <dds-link-list-item-cta cta-type="local" href="https://www.ibm.com/ca-en/products/offers-and-discounts?lnk=hpUSbt3" icon-placement="right" role="listitem" target="_self">
#                 Shop special offers and discounts
#
#             </dds-link-list-item-cta>
#         </dds-video-cta-container>
#
#
#
#
#
#
#
#             </dds-link-list>
#
#
#
#
#     </caem-intro-section>
# </div>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/paragraph.min.js" type="module"></script>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/heading.min.js" type="module"></script>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/intro-section.min.js" type="module"></script>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/brand-cta-section.min.js" type="module"></script>
# </div>
# <div class="card-group-pictogram-full-width card-group-pictogram">
#     <div class="bx--content-block">
#
#
#
#
#
#                 <caem-card-group cards-per-row="4" data-autoid="dds--card-group" grid-mode="border" style="--dds--card-group--cards-in-row:4">
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme="" cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/ca-en/artificial-intelligence?lnk=prodC" pictogram-placement="top" size="" target="_self">
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         AI &amp; machine learning</caem-card-heading>
#                     <svg class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" role="img" slot="pictogram" width="48">
#                         <use href="#ai"></use>
#                     </svg>
#                     <p>Use IBM Watsonx’s AI or build your own machine learning models</p>
#                     <caem-card-cta-footer color-scheme="" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/ca-en/artificial-intelligence?lnk=prodC" icon-placement="right" parent-href="https://www.ibm.com/ca-en/artificial-intelligence?lnk=prodC" slot="footer" target="_self">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg id="ai" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M16.195,31.36c-6.421,0-12.169-4.007-14.399-10.002 C1.051,21.408,0.373,20.771,0.372,20c0-0.75,0.61-1.36,1.36-1.36s1.36,0.61,1.36,1.36c0,0.474-0.243,0.892-0.611,1.135 c2.133,5.698,7.604,9.505,13.714,9.505c6.446,0,11.919-4.301,13.773-10.22c-1.448,2.06-3.877,3.44-6.565,3.44 c-3.822,0-7.066-2.785-7.664-6.525C15.113,17.212,14.64,16.661,14.64,16c0-0.584,0.37-1.083,0.888-1.275 c-0.608-3.421-3.615-5.962-7.125-5.962c-3.947,0-7.04,3.176-7.042,7.231c0,0.002,0,0.004,0,0.006H0.64c0-0.002,0-0.004,0-0.007 C0.644,7.526,7.445,0.64,15.805,0.64c6.42,0,12.168,4.006,14.399,10.001c0.777-0.034,1.425,0.587,1.425,1.358 c0,0.75-0.61,1.36-1.36,1.36s-1.36-0.61-1.36-1.36c0-0.473,0.243-0.891,0.611-1.135C27.387,5.166,21.916,1.36,15.805,1.36 c-6.319,0-11.704,4.134-13.659,9.873c1.402-1.949,3.662-3.19,6.256-3.19c3.881,0,7.204,2.826,7.846,6.62 C16.88,14.779,17.36,15.335,17.36,16c0,0.589-0.376,1.092-0.901,1.28c0.567,3.363,3.496,5.859,6.943,5.859 c3.857,0,7.127-3.118,7.235-6.851c0.001-0.096,0.002-0.192,0.002-0.289h0.721c0,0.033,0,0.065-0.001,0.098h0.001 c0,0.069-0.001,0.138-0.003,0.207C31.196,24.634,24.456,31.36,16.195,31.36z M1.732,19.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S2.085,19.36,1.732,19.36z M16,15.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S16.353,15.36,16,15.36z M30.269,11.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S30.621,11.36,30.269,11.36z"></path></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme="" cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/ca-en/analytics?lnk=ProdC" pictogram-placement="top" size="" target="_self">
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         Analytics</caem-card-heading>
#                     <svg class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" role="img" slot="pictogram" width="48">
#                         <use href="#predictive-analytics"></use>
#                     </svg>
#                     <p>Aggregate and analyze large datasets</p>
#                     <caem-card-cta-footer color-scheme="" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/ca-en/analytics?lnk=ProdC" icon-placement="right" parent-href="https://www.ibm.com/ca-en/analytics?lnk=ProdC" slot="footer" target="_self">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg id="predictive-analytics" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M31,31.36H1c-0.199,0-0.36-0.161-0.36-0.36 V1h0.72v29.64h4.28v-7.328c-0.576-0.158-1-0.687-1-1.312c0-0.75,0.61-1.36,1.36-1.36c0.364,0,0.694,0.144,0.938,0.377l3.702-2.221 v-8.484c-0.576-0.158-1-0.686-1-1.312c0-0.75,0.61-1.36,1.36-1.36S12.36,8.25,12.36,9c0,0.625-0.424,1.153-1,1.312v8.053l3.33-1.998 c-0.032-0.116-0.05-0.239-0.05-0.366c0-0.75,0.61-1.36,1.36-1.36c0.364,0,0.695,0.144,0.939,0.377l3.701-2.221V6.312 c-0.575-0.158-1-0.686-1-1.312c0-0.75,0.61-1.36,1.36-1.36S22.36,4.25,22.36,5c0,0.625-0.425,1.153-1,1.312v6.053l3.33-1.998 c-0.033-0.117-0.05-0.24-0.05-0.367c0-0.75,0.61-1.36,1.36-1.36s1.36,0.61,1.36,1.36c0,0.625-0.425,1.153-1,1.312V30.64H31V31.36z M21.36,30.64h4.279V11.312c-0.22-0.061-0.418-0.175-0.578-0.328l-3.701,2.221V30.64z M16.36,30.64h4.28V13.636l-3.33,1.998 c0.033,0.116,0.05,0.239,0.05,0.366c0,0.625-0.425,1.153-1,1.312V30.64z M11.36,30.64h4.28V17.312 c-0.22-0.061-0.418-0.175-0.579-0.328l-3.702,2.221V30.64H11.36z M6.36,30.64h4.28V19.636l-3.33,1.998 C7.343,21.75,7.36,21.873,7.36,22c0,0.625-0.424,1.153-1,1.312V30.64z M6,21.36c-0.353,0-0.64,0.287-0.64,0.64S5.647,22.64,6,22.64 S6.64,22.353,6.64,22S6.353,21.36,6,21.36z M16,15.36c-0.353,0-0.64,0.287-0.64,0.64s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64 S16.353,15.36,16,15.36z M26,9.36c-0.353,0-0.64,0.287-0.64,0.64s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S26.353,9.36,26,9.36z M11,8.36c-0.353,0-0.64,0.287-0.64,0.64S10.647,9.64,11,9.64S11.64,9.353,11.64,9S11.353,8.36,11,8.36z M21,4.36 c-0.353,0-0.64,0.287-0.64,0.64S20.647,5.64,21,5.64S21.64,5.353,21.64,5S21.353,4.36,21,4.36z"></path></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme="" cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/ca-en/servers?lnk=ProdC" pictogram-placement="top" size="" target="_self">
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         Compute &amp; servers</caem-card-heading>
#                     <svg class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" role="img" slot="pictogram" width="48">
#                         <use href="#storage--product"></use>
#                     </svg>
#                     <p>Run workloads on hybrid cloud infrastructure</p>
#                     <caem-card-cta-footer color-scheme="" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/ca-en/servers?lnk=ProdC" icon-placement="right" parent-href="https://www.ibm.com/ca-en/servers?lnk=ProdC" slot="footer" target="_self">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
# ...
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-l.ts=1698259957000.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-m-retina.ts=1698259957000.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-m.ts=1698259957000.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-s-retina.ts=1698259957000.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-s.ts=1698259957000.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-xs-retina.ts=1698259957000.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-xs.ts=1698259957000.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow aria-hidden="true" class="bx--card__eyebrow" slot="eyebrow">
#             Careers at IBM
#         </dds-card-eyebrow>
#         <dds-card-heading aria-level="3" class="bx--card__heading" role="heading" slot="heading">
#             From safer food supply to ethical AI, tackle the world's toughest problems
#         </dds-card-heading>
#
#         <dds-card-cta-footer aria-hidden="true" class="bx--card__footer-icon-size" cta-type="local" href="https://www.ibm.com/careers/search?q=CANADA" icon-placement="right" slot="footer" target="_self">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <dds-card-group-item cta-type="local" href="https://research.ibm.com/?lnk=hpUSAp" pictogram-placement="top" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="A large quantum server at IBM Research " default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xl.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image" id="image--1133661159" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xl-retina.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xl.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-l-retina.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-l.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-m-retina.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-m.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-s-retina.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-s.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xs-retina.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xs.ts=1704908933439.png/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow aria-hidden="true" class="bx--card__eyebrow" slot="eyebrow">
#             IBM Research
#         </dds-card-eyebrow>
#         <dds-card-heading aria-level="3" class="bx--card__heading" role="heading" slot="heading">
#             See the latest technology developed by IBM scientists and design thinkers
#         </dds-card-heading>
#
#         <dds-card-cta-footer aria-hidden="true" class="bx--card__footer-icon-size" cta-type="local" href="https://research.ibm.com/?lnk=hpUSAp" icon-placement="right" slot="footer" target="_self">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <dds-card-group-item cta-type="external" href="https://skillsbuild.org/?lnk=hpusap" pictogram-placement="top" target="_blank">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Portrait of tech worker in front of giant server" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image" id="image-1536779735" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl-retina.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-l-retina.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-l.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-m-retina.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-m.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-s-retina.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-s.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xs-retina.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xs.ts=1704908933475.jpg/content/adobe-cms/ca/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow aria-hidden="true" class="bx--card__eyebrow" slot="eyebrow">
#             Training and skills
#         </dds-card-eyebrow>
#         <dds-card-heading aria-level="3" class="bx--card__heading" role="heading" slot="heading">
#             Power your future in tech with job skills, courses and credentials—for free
#         </dds-card-heading>
#
#         <dds-card-cta-footer aria-hidden="true" class="bx--card__footer-icon-size" cta-type="external" href="https://skillsbuild.org/?lnk=hpusap" icon-placement="right" slot="footer" target="_blank">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <dds-card-group-item cta-type="video" href="1_qwhqg8r8" pictogram-placement="top" target="_self" video-name="What will AI mean for business and society? Watch IBM’s Dario Gil explain.">
#
#
#
#
#         <dds-card-eyebrow aria-hidden="true" class="bx--card__eyebrow" slot="eyebrow">
#             Preview AI Academy
#         </dds-card-eyebrow>
#
#
#         <dds-card-cta-footer aria-hidden="true" class="bx--card__footer-icon-size" cta-type="video" href="1_qwhqg8r8" icon-placement="right" slot="footer">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#                 </dds-card-group>
#
#
#
#
#
#
#
#
#
#
#
#
#         </dds-content-block-cards>
#     </dds-video-cta-container>
#
#
# </div>
#
#
#     </div>
#
# </dds-table-of-contents>
# </div>
# <div class="footer">
#
#
#
#
#     <dds-footer-container class="cmp-footer" data-autoid="dds--footer" data-children-count="0" data-cmp-is="footer" size="tall"></dds-footer-container>
#
#
# </div>
#
#
#     </div>
#
# </div>
#
#
# <dds-lightbox-video-player-container></dds-lightbox-video-player-container>
#
#
#
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlBundle.min.ACSHASH23cc0b9b9a73c9dd94381f29bf133f8a.js"></script>
#
#
#
#
#
#     <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-target-antiflicker.min.ACSHASH36a1efb28e947b5873f4a28c2cf9d5eb.js"></script>
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlWebComponents.min.ACSHASHaa58d161067036934162c981c49c78ef.js"></script>
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStyles.min.ACSHASH897814ade1034ba3448bfb2b0b09fde1.js"></script>
#
#
#
# <script async="" defer="" src="https://www.ibm.com/common/digitaladvisor/cm-app/latest/cm-app.min.js"></script>
#
#
#
#
#
#
#
#
#
#
#
# <script src="/4IVh5/EuUD/i5ub/Zp/mcxFZ/ua9DSDSJDfEu/RUpYAQ/RngwRmo/ZKEQ" type="text/javascript"></script><link href="/_sec/cp_challenge/sec-4-1.css" rel="stylesheet" type="text/css"/>
#                                         <script async="" defer="" src="/_sec/cp_challenge/sec-cpt-4-1.js"></script>
#                                         <div id="sec-overlay" style="display:none;">
#                                         <div id="sec-container">
#                                         </div>
#                                       </div>
# </body></html>

# %%
# SCRAP ALL LINKS
for link in soup.find_all('a', href = True):
    print(link.get('href'))
# Out:
# https://www.ibm.com/ca-en/cloud?lnk=hpUSbt1

# %%
# Scrap all image tags
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))

# %% [markdown]
# ### SCARP DATA FROM HTML TABLES

# %%
#Given a URL having tables with colors and its data in it 333 ROws and 5 columns
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %%
data = requests.get(url).text
data
# Out:
# '<html>\n   <body>\n      <h1>Partital List  of HTML5 Supported Colors</h1>\n<table border ="1" class="main-table">\n   <tr>\n      <td>Number </td>\n      <td>Color</td>\n      <td>Color Name</td>\n      <td>Hex Code<br>#RRGGBB</td>\n      <td>Decimal Code<br>(R,G,B)</td>\n   </tr>\n   <tr>\n      <td>1</td>\n      <td style="background:lightsalmon;">&nbsp;</td>\n      <td>lightsalmon</td>\n      <td>#FFA07A</td>\n      <td>rgb(255,160,122)</td>\n   </tr>\n   <tr>\n      <td>2</td>\n      <td style="background:salmon;">&nbsp;</td>\n      <td>salmon</td>\n      <td>#FA8072</td>\n      <td>rgb(250,128,114)</td>\n   </tr>\n   <tr>\n      <td>3</td>\n      <td style="background:darksalmon;">&nbsp;</td>\n      <td>darksalmon</td>\n      <td>#E9967A</td>\n      <td>rgb(233,150,122)</td>\n   </tr>\n   <tr>\n      <td>4</td>\n      <td style="background:lightcoral;">&nbsp;</td>\n      <td>lightcoral</td>\n      <td>#F08080</td>\n      <td>rgb(240,128,128)</td>\n   </tr>\n   <tr>\n      <td>5</td>\n      <td style="background:coral;">&nbsp;</td>\n      <td>coral</td>\n      <td>#FF7F50</td>\n      <td>rgb(255,127,80)</td>\n   </tr>\n   <tr>\n      <td>6</td>\n      <td style="background:tomato;">&nbsp;</td>\n      <td>tomato</td>\n      <td>#FF6347</td>\n      <td>rgb(255,99,71)</td>\n   </tr>\n   <tr>\n      <td>7</td>\n      <td style="background:orangered;">&nbsp;</td>\n      <td>orangered</td>\n      <td>#FF4500</td>\n      <td>rgb(255,69,0)</td>\n   </tr>\n   <tr>\n      <td>8</td>\n      <td style="background:gold;">&nbsp;</td>\n      <td>gold</td>\n      <td>#FFD700</td>\n      <td>rgb(255,215,0)</td>\n   </tr>\n   <tr>\n      <td>9</td>\n      <td style="background:orange;">&nbsp;</td>\n      <td>orange</td>\n      <td>#FFA500</td>\n      <td>rgb(255,165,0)</td>\n   </tr>\n   <tr>\n      <td>10</td>\n      <td style="background:darkorange;">&nbsp;</td>\n      <td>darkorange</td>\n      <td>#FF8C00</td>\n      <td>rgb(255,140,0)</td>\n   </tr>\n   <tr>\n      <td>11</td>\n      <td style="background:lightyellow;">&nbsp;</td>\n      <td>lightyellow</td>\n      <td>#FFFFE0</td>\n      <td>rgb(255,255,224)</td>\n   </tr>\n   <tr>\n      <td>12</td>\n      <td style="background:lemonchiffon;">&nbsp;</td>\n      <td>lemonchiffon</td>\n      <td>#FFFACD</td>\n      <td>rgb(255,250,205)</td>\n   </tr>\n   <tr>\n      <td>13</td>\n      <td style="background:papayawhip;">&nbsp;</td>\n      <td>papayawhip</td>\n      <td>#FFEFD5</td>\n      <td>rgb(255,239,213)</td>\n   </tr>\n   <tr>\n      <td>14</td>\n      <td style="background:moccasin;">&nbsp;</td>\n      <td>moccasin</td>\n      <td>#FFE4B5</td>\n      <td>rgb(255,228,181)</td>\n   </tr>\n   <tr>\n      <td>15</td>\n      <td style="background:peachpuff;">&nbsp;</td>\n      <td>peachpuff</td>\n      <td>#FFDAB9</td>\n      <td>rgb(255,218,185)</td>\n   </tr>\n   <tr>\n      <td>16</td>\n      <td style="background:palegoldenrod;">&nbsp;</td>\n      <td>palegoldenrod</td>\n      <td>#EEE8AA</td>\n      <td>rgb(238,232,170)</td>\n   </tr>\n   <tr>\n      <td>17</td>\n      <td style="background:khaki;">&nbsp;</td>\n      <td>khaki</td>\n      <td>#F0E68C</td>\n      <td>rgb(240,230,140)</td>\n   </tr>\n   <tr>\n      <td>18</td>\n      <td style="background:darkkhaki;">&nbsp;</td>\n      <td>darkkhaki</td>\n      <td>#BDB76B</td>\n      <td>rgb(189,183,107)</td>\n   </tr>\n   <tr>\n      <td>19</td>\n      <td style="background:yellow;">&nbsp;</td>\n      <td>yellow</td>\n      <td>#FFFF00</td>\n      <td>rgb(255,255,0)</td>\n   </tr>\n   <tr>\n      <td>20</td>\n      <td style="background:lawngreen;">&nbsp;</td>\n      <td>lawngreen</td>\n      <td>#7CFC00</td>\n      <td>rgb(124,252,0)</td>\n   </tr>\n   <tr>\n      <td>21</td>\n      <td style="background:chartreuse;">&nbsp;</td>\n      <td>chartreuse</td>\n      <td>#7FFF00</td>\n      <td>rgb(127,255,0)</td>\n   </tr>\n   <tr>\n      <td>22</td>\n      <td style="background:limegreen;">&nbsp;</td>\n      <td>limegreen</td>\n  ...

# %%
soup = BeautifulSoup(data, 'html5lib')
soup
# Out:
# <html><head></head><body>
#       <h1>Partital List  of HTML5 Supported Colors</h1>
# <table border="1" class="main-table">
#    <tbody><tr>
#       <td>Number </td>
#       <td>Color</td>
#       <td>Color Name</td>
#       <td>Hex Code<br/>#RRGGBB</td>
#       <td>Decimal Code<br/>(R,G,B)</td>
#    </tr>
#    <tr>
#       <td>1</td>
#       <td style="background:lightsalmon;"> </td>
#       <td>lightsalmon</td>
#       <td>#FFA07A</td>
#       <td>rgb(255,160,122)</td>
#    </tr>
#    <tr>
#       <td>2</td>
#       <td style="background:salmon;"> </td>
#       <td>salmon</td>
#       <td>#FA8072</td>
#       <td>rgb(250,128,114)</td>
#    </tr>
#    <tr>
#       <td>3</td>
#       <td style="background:darksalmon;"> </td>
#       <td>darksalmon</td>
#       <td>#E9967A</td>
#       <td>rgb(233,150,122)</td>
#    </tr>
#    <tr>
#       <td>4</td>
#       <td style="background:lightcoral;"> </td>
#       <td>lightcoral</td>
#       <td>#F08080</td>
#       <td>rgb(240,128,128)</td>
#    </tr>
#    <tr>
#       <td>5</td>
#       <td style="background:coral;"> </td>
#       <td>coral</td>
#       <td>#FF7F50</td>
#       <td>rgb(255,127,80)</td>
#    </tr>
#    <tr>
#       <td>6</td>
#       <td style="background:tomato;"> </td>
#       <td>tomato</td>
#       <td>#FF6347</td>
#       <td>rgb(255,99,71)</td>
#    </tr>
#    <tr>
#       <td>7</td>
#       <td style="background:orangered;"> </td>
#       <td>orangered</td>
#       <td>#FF4500</td>
#       <td>rgb(255,69,0)</td>
#    </tr>
#    <tr>
#       <td>8</td>
#       <td style="background:gold;"> </td>
#       <td>gold</td>
#       <td>#FFD700</td>
#       <td>rgb(255,215,0)</td>
#    </tr>
#    <tr>
#       <td>9</td>
#       <td style="background:orange;"> </td>
#       <td>orange</td>
#       <td>#FFA500</td>
#       <td>rgb(255,165,0)</td>
#    </tr>
#    <tr>
#       <td>10</td>
#       <td style="background:darkorange;"> </td>
#       <td>darkorange</td>
#       <td>#FF8C00</td>
#       <td>rgb(255,140,0)</td>
#    </tr>
#    <tr>
#       <td>11</td>
#       <td style="background:lightyellow;"> </td>
#       <td>lightyellow</td>
#       <td>#FFFFE0</td>
#       <td>rgb(255,255,224)</td>
#    </tr>
#    <tr>
#       <td>12</td>
#       <td style="background:lemonchiffon;"> </td>
#       <td>lemonchiffon</td>
#       <td>#FFFACD</td>
#       <td>rgb(255,250,205)</td>
#    </tr>
#    <tr>
#       <td>13</td>
#       <td style="background:papayawhip;"> </td>
#       <td>papayawhip</td>
#       <td>#FFEFD5</td>
#       <td>rgb(255,239,213)</td>
#    </tr>
#    <tr>
#       <td>14</td>
#       <td style="background:moccasin;"> </td>
#       <td>moccasin</td>
#       <td>#FFE4B5</td>
#       <td>rgb(255,228,181)</td>
#    </tr>
#    <tr>
#       <td>15</td>
#       <td style="background:peachpuff;"> </td>
#       <td>peachpuff</td>
#       <td>#FFDAB9</td>
#       <td>rgb(255,218,185)</td>
#    </tr>
#    <tr>
#       <td>16</td>
#       <td style="background:palegoldenrod;"> </td>
#       <td>palegoldenrod</td>
#       <td>#EEE8AA</td>
#       <td>rgb(238,232,170)</td>
#    </tr>
#    <tr>
#       <td>17</td>
#       <td style="background:khaki;"> </td>
#       <td>khaki</td>
#       <td>#F0E68C</td>
#       <td>rgb(240,230,140)</td>
#    </tr>
#    <tr>
#       <td>18</td>
#       <td style="background:darkkhaki;"> </td>
#       <td>darkkhaki</td>
#       <td>#BDB76B</td>
#       <td>rgb(189,183,107)</td>
#    </tr>
#    <tr>
#       <td>19</td>
#       <td style="background:yellow;"> </td>
#       <td>yellow</td>
#       <td>#FFFF00</td>
#       <td>rgb(255,255,0)</td>
#    </tr>
#    <tr>
#       <td>20</td>
#       <td style="background:lawngreen;"> </td>
#       <td>lawngreen</td>
#       <td>#7CFC00</td>
#       <td>rgb(124,252,0)</td>
#    </tr>
#    <tr>
#       <td>21</td>
#       <td style="background:chartreuse;"> </td>
#       <td>chartreuse</td>
#       <td>#7FFF00</td>
#       <td>rgb(127,255,0)</td>
#    </tr>
#    <tr>
#       <td>22</td>
#       <td style="background:limegreen;"> </td>
#       <td>limegreen</td>
#       <td>#32CD32</td>
#       <td>rgb(50,205,50)</td>
#    </tr>
#    <tr>
#       <td>23</td>
#       <td style="background:lime;"> </td>
#       <td>lime</td>
#       <td>#00FF00</td>
#       <td>rgb(0.255.0)</td>
#    </tr>
#    <tr>
#       <td>24</td>
#       <td style="background:forestgreen;"> </td>
#       <td>forestgreen</td>
#       <td>#228B22</td>
#       <td>rgb(34,139,34)</td>
#    </tr>
#    <tr>
#       <td>25</td>
#       <td style="background:green;"> </td>
#       <td>green</td>
#       <td>#008000</td>
#       <td>rgb(0,128,0)</td>
#    </tr>
#    <tr>
#       <td>26</td>
#       <td style="background:powderblue;"> </td>
#       <td>powderblue</td>
#       <td>#B0E0E6</td>
#       <td>rgb(176,224,230)</td>
#    </tr>
#    <tr>
#       <td>27</td>
#       <td style="background:lightblue;"> </td>
#       <td>lightblue</td>
#       <td>#ADD8E6</td>
#       <td>rgb(173,216,230)</td>
#    </tr>
#    <tr>
#       <td>28</td>
#       <td style="background:lightskyblue;"> </td>
#       <td>lightskyblue</td>
#       <td>#87CEFA</td>
#       <td>rgb(135,206,250)</td>
#    </tr>
#    <tr>
#       <td>29</td>
#       <td style="background:skyblue;"> </td>
#       <td>skyblue</td>
#       <td>#87CEEB</td>
#       <td>rgb(135,206,235)</td>
#    </tr>
#    <tr>
#       <td>30</td>
#       <td style="background:deepskyblue;"> </td>
#       <td>deepskyblue</td>
#       <td>#00BFFF</td>
#       <td>rgb(0,191,255)</td>
#    </tr>
#    <tr>
#       <td>31</td>
#       <td style="background:lightsteelblue;"> </td>
#       <td>lightsteelblue</td>
#       <td>#B0C4DE</td>
#       <td>rgb(176,196,222)</td>
#    </tr>
#    <tr>
#       <td>32</td>
#       <td style="background:dodgerblue;"> </td>
#       <td>dodgerblue</td>
#       <td>#1E90FF</td>
#       <td>rgb(30,144,255)</td>
#    </tr>
# </tbody></table>
#
# </body></html>

# %%
# FInd a html table in webpage
table = soup.find('table')

# %%
# get all rows from the table
# Out:
# [<td>Number </td>,
#  <td>Color</td>,
#  <td>Color Name</td>,
#  <td>Hex Code<br/>#RRGGBB</td>,
#  <td>Decimal Code<br/>(R,G,B)</td>,
#  <td>1</td>,
#  <td style="background:lightsalmon;"> </td>,
#  <td>lightsalmon</td>,
#  <td>#FFA07A</td>,
#  <td>rgb(255,160,122)</td>,
#  <td>2</td>,
#  <td style="background:salmon;"> </td>,
#  <td>salmon</td>,
#  <td>#FA8072</td>,
#  <td>rgb(250,128,114)</td>,
#  <td>3</td>,
#  <td style="background:darksalmon;"> </td>,
#  <td>darksalmon</td>,
#  <td>#E9967A</td>,
#  <td>rgb(233,150,122)</td>,
#  <td>4</td>,
#  <td style="background:lightcoral;"> </td>,
#  <td>lightcoral</td>,
#  <td>#F08080</td>,
#  <td>rgb(240,128,128)</td>,
#  <td>5</td>,
#  <td style="background:coral;"> </td>,
#  <td>coral</td>,
#  <td>#FF7F50</td>,
#  <td>rgb(255,127,80)</td>,
#  <td>6</td>,
#  <td style="background:tomato;"> </td>,
#  <td>tomato</td>,
#  <td>#FF6347</td>,
#  <td>rgb(255,99,71)</td>,
#  <td>7</td>,
#  <td style="background:orangered;"> </td>,
#  <td>orangered</td>,
#  <td>#FF4500</td>,
#  <td>rgb(255,69,0)</td>,
#  <td>8</td>,
#  <td style="background:gold;"> </td>,
#  <td>gold</td>,
#  <td>#FFD700</td>,
#  <td>rgb(255,215,0)</td>,
#  <td>9</td>,
#  <td style="background:orange;"> </td>,
#  <td>orange</td>,
#  <td>#FFA500</td>,
#  <td>rgb(255,165,0)</td>,
#  <td>10</td>,
#  <td style="background:darkorange;"> </td>,
#  <td>darkorange</td>,
#  <td>#FF8C00</td>,
#  <td>rgb(255,140,0)</td>,
#  <td>11</td>,
#  <td style="background:lightyellow;"> </td>,
#  <td>lightyellow</td>,
#  <td>#FFFFE0</td>,
#  <td>rgb(255,255,224)</td>,
#  <td>12</td>,
#  <td style="background:lemonchiffon;"> </td>,
#  <td>lemonchiffon</td>,
#  <td>#FFFACD</td>,
#  <td>rgb(255,250,205)</td>,
#  <td>13</td>,
#  <td style="background:papayawhip;"> </td>,
#  <td>papayawhip</td>,
#  <td>#FFEFD5</td>,
#  <td>rgb(255,239,213)</td>,
#  <td>14</td>,
#  <td style="background:moccasin;"> </td>,
#  <td>moccasin</td>,
#  <td>#FFE4B5</td>,
#  <td>rgb(255,228,181)</td>,
#  <td>15</td>,
#  <td style="background:peachpuff;"> </td>,
#  <td>peachpuff</td>,
#  <td>#FFDAB9</td>,
#  <td>rgb(255,218,185)</td>,
#  <td>16</td>,
#  <td style="background:palegoldenrod;"> </td>,
#  <td>palegoldenrod</td>,
#  <td>#EEE8AA</td>,
#  <td>rgb(238,232,170)</td>,
#  <td>17</td>,
#  <td style="background:khaki;"> </td>,
#  <td>khaki</td>,
#  <td>#F0E68C</td>,
#  <td>rgb(240,230,140)</td>,
#  <td>18</td>,
#  <td style="background:darkkhaki;"> </td>,
#  <td>darkkhaki</td>,
#  <td>#BDB76B</td>,
#  <td>rgb(189,183,107)</td>,
#  <td>19</td>,
#  <td style="background:yellow;"> </td>,
#  <td>yellow</td>,
#  <td>#FFFF00</td>,
#  <td>rgb(255,255,0)</td>,
#  <td>20</td>,
#  <td style="background:lawngreen;"> </td>,
#  <td>lawngreen</td>,
#  <td>#7CFC00</td>,
#  <td>rgb(124,252,0)</td>,
#  <td>21</td>,
#  <td style="background:chartreuse;"> </td>,
#  <td>chartreuse</td>,
#  <td>#7FFF00</td>,
#  <td>rgb(127,255,0)</td>,
#  <td>22</td>,
#  <td style="background:limegreen;"> </td>,
#  <td>limegreen</td>,
#  <td>#32CD32</td>,
#  <td>rgb(50,205,50)</td>,
#  <td>23</td>,
#  <td style="background:lime;"> </td>,
#  <td>lime</td>,
#  <td>#00FF00</td>,
#  <td>rgb(0.255.0)</td>,
#  <td>24</td>,
#  <td style="background:forestgreen;"> </td>,
#  <td>forestgreen</td>,
#  <td>#228B22</td>,
#  <td>rgb(34,139,34)</td>,
#  <td>25</td>,
#  <td style="background:green;"> </td>,
#  <td>green</td>,
#  <td>#008000</td>,
#  <td>rgb(0,128,0)</td>,
#  <td>26</td>,
#  <td style="background:powderblue;"> </td>,
#  <td>powderblue</td>,
#  <td>#B0E0E6</td>,
#  <td>rgb(176,224,230)</td>,
#  <td>27</td>,
#  <td style="background:lightblue;"> </td>,
#  <td>lightblue</td>,
#  <td>#ADD8E6</td>,
#  <td>rgb(173,216,230)</td>,
#  <td>28</td>,
#  <td style="background:lightskyblue;"> </td>,
#  <td>lightskyblue</td>,
#  <td>#87CEFA</td>,
#  <td>rgb(135,206,250)</td>,
#  <td>29</td>,
#  <td style="background:skyblue;"> </td>,
#  <td>skyblue</td>,
#  <td>#87CEEB</td>,
#  <td>rgb(135,206,235)</td>,
#  <td>30</td>,
#  <td style="background:deepskyblue;"> </td>,
#  <td>deepskyblue</td>,
#  <td>#00BFFF</td>,
#  <td>rgb(0,191,255)</td>,
#  <td>31</td>,
#  <td style="background:lightsteelblue;"> </td>,
#  <td>lightsteelblue</td>,
#  <td>#B0C4DE</td>,
#  <td>rgb(176,196,222)</td>,
#  <td>32</td>,
#  <td style="background:dodgerblue;"> </td>,
#  <td>dodgerblue</td>,
#  <td>#1E90FF</td>,
#  <td>rgb(30,144,255)</td>]

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].string # store the value in column 3 as color_name
    color_code = cols[3].text # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ### Scarping tables from a WEB PAGE USING PANDAS

# %%
# Particularly for extratcing tabular data from webpage we can use read_html() of pandas
import pandas as pd
tables = pd.read_html(url)

# %%
tables[0]
# Out:
#          0      1               2                 3                     4
# 0   Number  Color      Color Name  Hex Code #RRGGBB  Decimal Code (R,G,B)
# 1        1    NaN     lightsalmon           #FFA07A      rgb(255,160,122)
# 2        2    NaN          salmon           #FA8072      rgb(250,128,114)
# 3        3    NaN      darksalmon           #E9967A      rgb(233,150,122)
# 4        4    NaN      lightcoral           #F08080      rgb(240,128,128)
# 5        5    NaN           coral           #FF7F50       rgb(255,127,80)
# 6        6    NaN          tomato           #FF6347        rgb(255,99,71)
# 7        7    NaN       orangered           #FF4500         rgb(255,69,0)
# 8        8    NaN            gold           #FFD700        rgb(255,215,0)
# 9        9    NaN          orange           #FFA500        rgb(255,165,0)
# 10      10    NaN      darkorange           #FF8C00        rgb(255,140,0)
# 11      11    NaN     lightyellow           #FFFFE0      rgb(255,255,224)
# 12      12    NaN    lemonchiffon           #FFFACD      rgb(255,250,205)
# 13      13    NaN      papayawhip           #FFEFD5      rgb(255,239,213)
# 14      14    NaN        moccasin           #FFE4B5      rgb(255,228,181)
# 15      15    NaN       peachpuff           #FFDAB9      rgb(255,218,185)
# 16      16    NaN   palegoldenrod           #EEE8AA      rgb(238,232,170)
# 17      17    NaN           khaki           #F0E68C      rgb(240,230,140)
# 18      18    NaN       darkkhaki           #BDB76B      rgb(189,183,107)
# 19      19    NaN          yellow           #FFFF00        rgb(255,255,0)
# 20      20    NaN       lawngreen           #7CFC00        rgb(124,252,0)
# 21      21    NaN      chartreuse           #7FFF00        rgb(127,255,0)
# 22      22    NaN       limegreen           #32CD32        rgb(50,205,50)
# 23      23    NaN            lime           #00FF00          rgb(0.255.0)
# 24      24    NaN     forestgreen           #228B22        rgb(34,139,34)
# 25      25    NaN           green           #008000          rgb(0,128,0)
# 26      26    NaN      powderblue           #B0E0E6      rgb(176,224,230)
# 27      27    NaN       lightblue           #ADD8E6      rgb(173,216,230)
# 28      28    NaN    lightskyblue           #87CEFA      rgb(135,206,250)
# 29      29    NaN         skyblue           #87CEEB      rgb(135,206,235)
# 30      30    NaN     deepskyblue           #00BFFF        rgb(0,191,255)
# 31      31    NaN  lightsteelblue           #B0C4DE      rgb(176,196,222)
# 32      32    NaN      dodgerblue           #1E90FF       rgb(30,144,255)
